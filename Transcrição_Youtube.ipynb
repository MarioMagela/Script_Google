# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioMagela/Script_Google/blob/main/Transcri%C3%A7%C3%A3o_Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar a biblioteca necessária
# !pip install youtube-transcript-api
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2024.12.14)
# Downloading youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.3

# %%
# Função para extrair o ID do vídeo a partir da URL
def get_video_id(url):
    """
    Extrai o ID do vídeo a partir de uma URL do YouTube.
    :param url: URL completa do vídeo.
    :return: ID do vídeo.
    """
    if "v=" in url:
        return url.split("v=")[-1].split("&")[0]
    elif "youtu.be/" in url:
        return url.split("youtu.be/")[-1]
    elif "youtube.com/live/" in url:
        return url.split("youtube.com/live/")[-1]
    else:
        return url

# %%
# Função para extrair a transcrição
def extract_transcription(video_url, language="pt"):
    """
    Extrai a transcrição de um vídeo do YouTube.
    :param video_url: URL do vídeo do YouTube.
    :param language: Idioma desejado para a transcrição (padrão: português).
    :return: Transcrição completa como texto.
    """
    try:
        # Extrair o ID do vídeo
        video_id = get_video_id(video_url)

        # Obter a transcrição do vídeo
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=[language])

        # Combinar o texto em uma única string
        full_transcription = " ".join([entry['text'] for entry in transcript])
        return full_transcription

    except Exception as e:
        return f"Erro ao obter a transcrição: {e}"

# %%
# Inserir o link do vídeo
video_url = input("Digite o link do vídeo do YouTube: ")
# Out:
# Digite o link do vídeo do YouTube: https://youtube.com/live/CJ1FZU0mfOM?feature=share

# %%
# Idioma desejado
language = "pt"

# %%
# Obter a transcrição
transcription = extract_transcription(video_url, language)

# %%
# Exibir a transcrição
print("\n### Transcrição Completa ###")
print(transcription)
# Out:
# ### Transcrição Completa ###
# [Música] muito bem Tô aqui com meu amigo aqui o Edson tudo bem Edson beleza máo tudo certo beleza seja bem-vindo ao foco na balavel é uma metodologia que cada dia eu venho Crescendo com ela para me ajudar a manter nos projetos Constância e tempo vai ser o tema de hoje viu então o tema de hoje vai ser tempo frequência Tá certo seja bem-vindo também Ronaldo valeu Ronaldo é professor na parte financeira um cara que ajuda os engenheiros a terem mais financeira né Ronaldo é isso é isso aí e aí vamos vamos que vamos Eu Eu sempre gosto de começar o foco inabalável pensando nessa imagem aqui ó é aquela questão da gente saber para onde vai o foco inabalável é você saber exatamente qual que é o próximo passo assim ó de forma muito Certeira sabe aqui não há espaço para plano b não aqui há espaço para decisão uma vez que você decidiu Poxa entendeu tenta eliminar as distrações e e pau vai em frente tem as ferramentas que eu vou mostrar que eu uso que me mantém no caminho mas mais do que tudo é saber para onde eu quero ir então isso aí é importantíssimo beleza vamos vão interagindo vai ter um momento aqui que eu vou pedir interação de vocês que é o seguinte ó o foco não é não eh foco é não fazer o que não deve ser feito então parar de fazer determinadas coisas é importante para ter foco então vamos fazer um um exercício aqui de listar itens que eu estou fazendo e que tá me prejudicando Então vou dar algum tempinho aqui alguns minutinhos segundos pra gente pensar nisso aí pode fazer o seguinte ou me manda no individual ou me manda aqui no chat ou tem os comentários aqui também não sei se vocês T acesso escreve aí o que vocês vão parar de fazer ou seja mediante a objetivo que vocês têm que que vocês estão decididos de fazer não vocês irão fazer mesmo mas o que vocês vão parar de fazer eu também vou escrever aqui [Música] tá tempo [Música] [Música] [Música] Opa [Música] voltei escreve aí para mim que que vocês vão parar de fazer Vou colocar aqui você me manda ou fala aí fala para mim Ronaldo Endo aqui pode esm Ah eu vendo aqui end recebe dos grupos e vai tentar acompanhar disciplina no uso do WhatsApp do Instagram do YouTube tem que ter disciplina tô perando tempo com a internet Como eu como eu moro aqui só aí fica difícil chega o dia todo Chega mas aqui tá embaçando tô vendo a gente vai a gente vai quebrar isso agora eu eu falo porque eu consegui superar isso aí vou falar como hein ó também falou vamos falar um de cada um aqui ó o primeiro aqui vamos pegar do Ronaldo passar para essa visualização aqui mais tranquilo ó o Ronaldo falou de perder tempo com internet a primeira [Música] sua voz fugiu máo é uma máquina Opa voltei tá falhando a gente vai ter problema aqui tá falhando agora voltou voltou voltou Tá bom vou fazer o plano B aqui queer passar pro qualquer coisa eu passo pro aqui no roteador do do celular se der uma falha de mas por enquanto vocês estão que travou he agora foi aí voltou agora tá bem melhor tô eu tô no celular aqui no na internet do celular agora vai vai com tudo então o seguinte a primeira premissa da internet de tempo na internet é o seguinte Esses aparelhinhos foram feitos para aprender a nossa tensão ah seja bem-vindo aí Kelly tudo certo obrigado por comparecer desculpa por avisar em cima Kelly muito Perdão minha parte a gente tá aqui falando do fque na abalável eh talvez para você falar você vai ter que se desmutar aí tá Kelly aí se você quiser interagir tá bom Beleza então é o seguinte a gente falou que o foco é parar de fazer o que não deve ser feito tá existe a falsa preguiça A falsa preguiça ela tá disfarçada muitas vezes de muitas tarefas então eu acabo fazendo coisas mais gostosinhas coisas que eu não quero enfrentar e aí fica ocupando o tempo daquilo que realmente eu preciso enfrentar então assim começou o dia tentar programar as tarefas mais importantes mais urgentes no início do dia não deixar empurrar com a barriga isso não certo então o a primeira problema aí é tempo com a internet e falando propriamente di ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Definir o caminho para salvar no Google Drive
caminho_drive = "/content/drive/My Drive/transcricao_youtube.txt"

# %%
# Salvar a transcrição no Google Drive
with open(caminho_drive, "w", encoding="utf-8") as file:
    file.write(transcription)
    print(f"\nA transcrição foi salva no arquivo: {caminho_drive}")
# Out:
# A transcrição foi salva no arquivo: /content/drive/My Drive/transcricao_youtube.txt
